# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import fcluster
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# %%
source="Online Retail.xlsx"
dataset=pd.read_excel(source)
dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # Thông tin chi tiết về  dữ liệu

# %%
dataset.shape
# Out:
# (541909, 8)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# # Dữ liệu bị mất

# %%
msno.matrix(dataset)
# Out:
# <Axes: >

# %% [markdown]
# # Xử lý dữ liệu

# %%
# Lọc xóa các dữ liệu có thuộc tính bị mất
dataset=dataset.loc[pd.isnull(dataset.CustomerID) == False] # Lọc các hàng có giá trị null

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
msno.matrix(dataset)
# Out:
# <Axes: >

# %%
# Mô tả chi tiết toàn bộ DataFrame
dataset.describe(include='all', datetime_is_numeric=True)
# Out:
#         InvoiceNo StockCode                         Description  \
# count    406829.0    406829                              406829
# unique    22190.0      3684                                3896
# top      576339.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        542.0      2077                                2070
# mean          NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
#
#              Quantity                    InvoiceDate      UnitPrice  \
# count   406829.000000                         406829  406829.000000
# unique            NaN                            NaN            NaN
# top               NaN                            NaN            NaN
# freq              NaN                            NaN            NaN
# mean        12.061303  2011-07-10 16:30:57.879207424       3.460471
# min     -80995.000000            2010-12-01 08:26:00       0.000000
# 25%          2.000000            2011-04-06 15:02:00       1.250000
# 50%          5.000000            2011-07-31 11:48:00       1.950000
# 75%         12.000000            2011-10-20 13:06:00       3.750000
# max      80995.000000            2011-12-09 12:50:00   38970.000000
# std        248.693370                            NaN      69.315162
#
#            CustomerID         Country
# count   406829.000000          406829
# unique            NaN              37
# top               NaN  United Kingdom
# freq              NaN          361878
# mean     15287.690570             NaN
# min      12346.000000             NaN
# 25%      13953.000000             NaN
# 50%      15152.000000             NaN
# 75%      16791.000000             NaN
# max      18287.000000             NaN
# std       1713.600303             NaN

# %%
#Loại bỏ các hàng có Quantity < 0
dataset=dataset[dataset['Quantity']>0]

# %%
#Loại bỏ các hàng mà  cột Customer có giá trị là NaN
dataset.dropna(subset=['CustomerID'],how='all',inplace=True)

# %%
dataset.shape
# Out:
# (397924, 8)

# %% [markdown]
# # Xây dựng mô hình RFM

# %% [markdown]
# - RECENCY (R): Số ngày kể từ lần mua cuối cùng
# - FREQUENCY (F): Tổng số lần mua hàng
# - MONETARY VALUE (M): Tổng số tiền khách hàng này đã chi tiêu.

# %% [markdown]
# ## Recency
# * Để tính toán lần mua gần đây cần chọn một ngày làm mốc mà từ đó đánh giá được lần mua hàng gần đây nhất của khách hàng là bao nhiêu ngày.

# %%
# Thời gian cuối cùng trong dataset
dataset['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
now = dt.date(2011,12,10)
print(now)
# Out:
# 2011-12-10

# %%
#Tạo 1 cột mới có tên là “date” chỉ chứa duy nhất ngày lập hóa đơn
dataset['date'] = dataset['InvoiceDate'].dt.date

# %%
dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country        date
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01

# %% [markdown]
# #### Recency dataset

# %%
# Nhóm theo khách hàng và kiểm tra ngày mua hàng cuối cùng sau đó lưu vào cột "LastPurshaceDate"
recency_data = dataset.groupby(by='CustomerID', as_index=False)['date'].max()
recency_data.columns = ['CustomerID','LastPurshaceDate']
recency_data.head()
# Out:
#    CustomerID LastPurshaceDate
# 0     12346.0       2011-01-18
# 1     12347.0       2011-12-07
# 2     12348.0       2011-09-25
# 3     12349.0       2011-11-21
# 4     12350.0       2011-02-02

# %%
#Tính toán số ngày mua gần đây và lưu vào cột "Recency"
recency_data['Recency'] = recency_data['LastPurshaceDate'].apply(lambda x: (now - x).days)

# %%
recency_data.head()
# Out:
#    CustomerID LastPurshaceDate  Recency
# 0     12346.0       2011-01-18      326
# 1     12347.0       2011-12-07        3
# 2     12348.0       2011-09-25       76
# 3     12349.0       2011-11-21       19
# 4     12350.0       2011-02-02      311

# %%
#Bỏ cột LastPurshaceDate vì k cần dùng đến nữa
recency_data.drop('LastPurshaceDate',axis=1,inplace=True)

# %%
recency_data.head()
# Out:
#    CustomerID  Recency
# 0     12346.0      326
# 1     12347.0        3
# 2     12348.0       76
# 3     12349.0       19
# 4     12350.0      311

# %% [markdown]
# ## Frequency
# Để tính được thuộc tính nay·, cần kiểm tra xem có bao nhiêu hóa đơn được đăng ký bởi cùng một khách hàng.

# %%
data_copy=dataset
#Loại bỏ các bản ghi có cùng mã hóa đơn và Id khách hàng
data_copy.drop_duplicates(subset=['InvoiceNo', 'CustomerID'], keep="first", inplace=True)
#Tính toán tần suất mua hàng cho mỗi khách hàng
frequency_data = data_copy.groupby(by=['CustomerID'], as_index=False)['InvoiceNo'].count()
frequency_data.columns = ['CustomerID','Frequency']
frequency_data.head()
# Out:
#    CustomerID  Frequency
# 0     12346.0          1
# 1     12347.0          7
# 2     12348.0          4
# 3     12349.0          1
# 4     12350.0          1

# %% [markdown]
# ## Monetary
#
# Thuộc tính Monetary trả lời câu hỏi: Khách hàng đã chi bao nhiêu tiền trong thời gian đó?
# Để tính toán được giá trị của thuộc tính này ta cần thêm 1 thuộc tính tổng tiền mua hàng (TotalCost = Quantity * UnitPrice)

# %%
#Tạo 1 cột tổng tiền
dataset['TotalCost'] = dataset['Quantity'] * dataset['UnitPrice']

# %%
# Tính toán tổng tiền cho mỗi khách hàng đã chi tiêu
monetary_data = dataset.groupby(by='CustomerID',as_index=False).agg({'TotalCost': 'sum'})
monetary_data.columns = ['CustomerID','Monetary']
monetary_data.head()
# Out:
#    CustomerID  Monetary
# 0     12346.0  77183.60
# 1     12347.0    163.16
# 2     12348.0    331.36
# 3     12349.0     15.00
# 4     12350.0     25.20

# %% [markdown]
# ## Tạo bảng RFM
# Hợp nhất dữ liệu recency, frequency, monetary

# %%
rfm= recency_data.merge(frequency_data.merge(monetary_data,on='CustomerID'),on='CustomerID')
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     12346.0      326          1  77183.60
# 1     12347.0        3          7    163.16
# 2     12348.0       76          4    331.36
# 3     12349.0       19          1     15.00
# 4     12350.0      311          1     25.20

# %%
rfm.shape
# Out:
# (4339, 4)

# %%
# Phân tích giá trị ngoại lai của recency, frequency, monetary
attributes = ['Recency','Frequency','Monetary']
plt.rcParams['figure.figsize'] = [6,4]
sns.boxplot(data = rfm[attributes], orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
plt.ylabel("Range", fontweight = 'bold')
plt.xlabel("Attributes", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Attributes')

# %%
# Loại bỏ các giá trị ngoại lai cho Recency
Q1 = rfm.Recency.quantile(0.25)
Q3 = rfm.Recency.quantile(0.75)
IQR = Q3 - Q1
rfm = rfm[(rfm.Recency >= Q1 - 1.5*IQR) & (rfm.Recency <= Q3 + 1.5*IQR)]

# Loại bỏ các giá trị ngoại lai cho Frequency
Q1 = rfm.Frequency.quantile(0.25)
Q3 = rfm.Frequency.quantile(0.75)
IQR = Q3 - Q1
rfm = rfm[(rfm.Frequency >= Q1 - 1.5*IQR) & (rfm.Frequency <= Q3 + 1.5*IQR)]

# Loại bỏ các giá trị ngoại lai cho Monetary
Q1 = rfm.Monetary.quantile(0.25)
Q3 = rfm.Monetary.quantile(0.75)
IQR = Q3 - Q1
rfm = rfm[(rfm.Monetary >= Q1 - 1.5*IQR) & (rfm.Monetary <= Q3 + 1.5*IQR)]

# %%
# Phân tích giá trị ngoại lai của recency, frequency, monetary
attributes = ['Recency','Frequency','Monetary']
plt.rcParams['figure.figsize'] = [4,3]
sns.boxplot(data = rfm[attributes], orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
plt.ylabel("Range", fontweight = 'bold')
plt.xlabel("Attributes", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Attributes')

# %%
rfm_df = rfm[['Frequency', 'Recency', 'Monetary']]

# Chuẩn hóa dữ liệu
scaler = StandardScaler()

rfm_df_scaled = scaler.fit_transform(rfm_df)
rfm_df_scaled.shape
# Out:
# (3539, 3)

# %%
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['Frequency', 'Recency', 'Monetary']
rfm_df_scaled.head()
# Out:
#    Frequency   Recency  Monetary
# 0   1.948929 -0.981552  1.935755
# 1  -0.818647 -0.802773 -0.769124
# 2  -0.818647  2.459947 -0.582908
# 3  -0.818647  1.275535 -0.679667
# 4  -0.818647  1.588398 -0.663236

# %% [markdown]
# # Triển khai thuật toán K-means

# %%
# Tìm số lượng cụm tối ưu bằng Elbow Method
sse = []
k_range = range(2, 10)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(rfm_df_scaled)
    sse.append(kmeans.inertia_)

plt.figure(figsize=(8, 4))
plt.plot(k_range, sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of squared errors')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Huấn luyện mô hình K-means với số lượng cụm k
k = 3  # Số lượng cụm đã chọn từ Elbow Method
kmeans = KMeans(n_clusters=k, random_state=0)
kmeans.fit(rfm_df_scaled)

# Thêm cột 'cluster_km' vào DataFrame gốc
rfm['cluster_km'] = kmeans.labels_
rfm.head()
# Out:
# C:\Users\anhn2\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#    CustomerID  Recency  Frequency  Monetary  cluster_km
# 1     12347.0        3          7    163.16           0
# 3     12349.0       19          1     15.00           1
# 4     12350.0      311          1     25.20           2
# 6     12353.0      205          1     19.90           2
# 7     12354.0      233          1     20.80           2

# %%
# Vẽ biểu đồ phân cụm
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(rfm['Recency'], rfm['Frequency'], rfm['Monetary'], c=rfm['cluster_km'], cmap='viridis')

ax.set_title('3D Clustering of Customers')
ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetary')

# Tạo legend
legend1 = ax.legend(*scatter.legend_elements(), title="Clusters")
ax.add_artist(legend1)

plt.show()

# %%
# Tính toán các số liệu thống kê cho mỗi cụm
cluster_analysis = rfm.groupby('cluster_km').mean()
cluster_analysis['count_km'] = rfm['cluster_km'].value_counts()
cluster_analysis
# Out:
#               CustomerID     Recency  Frequency    Monetary  count_km
# cluster_km
# 0           15185.763789   38.607914   5.687050  132.644616       834
# 1           15343.695228   49.416486   2.067787   34.123281      1844
# 2           15319.569106  230.170732   1.468060   33.252033       861

# %%
# Tính phần trăm của mỗi cụm
cluster_counts = cluster_analysis['count_km']
cluster_percentages = cluster_counts / cluster_counts.sum() * 100

# Vẽ biểu đồ tròn
plt.figure(figsize=(4, 4))
plt.pie(cluster_percentages, labels=cluster_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(cluster_counts)))

plt.title('Phân phối % các nhóm khách hàng')
plt.axis('equal')  # Đảm bảo biểu đồ tròn
plt.show()

# %% [markdown]
# # Triển khai thuật toán Hierarchical Clustering

# %%
Z = linkage(rfm_df_scaled, method="complete", metric='euclidean')
dendrogram(Z)
plt.show()

# %%
# Xác định số lượng cụm từ dendrogram
num_clusters = 3
cluster_labels = fcluster(Z, num_clusters, criterion='maxclust')

# Gán nhãn cụm vào DataFrame RFM
rfm['cluster_hc'] = cluster_labels
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  cluster_km  cluster_hc
# 1     12347.0        3          7    163.16           0           2
# 3     12349.0       19          1     15.00           1           1
# 4     12350.0      311          1     25.20           2           1
# 6     12353.0      205          1     19.90           2           1
# 7     12354.0      233          1     20.80           2           1

# %%
# Vẽ biểu đồ phân cụm
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(rfm['Recency'], rfm['Frequency'], rfm['Monetary'], c=rfm['cluster_hc'], cmap='viridis')

ax.set_title('3D Clustering of Customers')
ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetary')

# Tạo legend
legend1 = ax.legend(*scatter.legend_elements(), title="Clusters")
ax.add_artist(legend1)

plt.show()

# %%
# Phân tích cụm
cluster_analysis = rfm.groupby('cluster_hc').mean()
cluster_analysis['count_hc'] = rfm['cluster_hc'].value_counts()
cluster_analysis.drop('cluster_km', axis=1, inplace=True)
cluster_analysis
# Out:
#               CustomerID     Recency  Frequency    Monetary  count_hc
# cluster_hc
# 1           15328.234214  111.260620   1.764256   36.251343      2613
# 2           15334.515896   27.374277   5.750000   89.026026       692
# 3           14891.833333   50.568376   5.260684  195.932350       234

# %%
# Tính phần trăm của mỗi cụm
cluster_counts = cluster_analysis['count_hc']
cluster_percentages = cluster_counts / cluster_counts.sum() * 100

# Vẽ biểu đồ tròn
plt.figure(figsize=(4, 4))
plt.pie(cluster_percentages, labels=cluster_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(cluster_counts)))

plt.title('Phân phối % các nhóm khách hàng')
plt.axis('equal')  # Đảm bảo biểu đồ tròn
plt.show()

# %% [markdown]
# # Đánh giá thuật toán

# %%
def evaluate_clustering(data, labels, name):
    silhouette_avg = silhouette_score(data, labels)
    davies_bouldin_avg = davies_bouldin_score(data, labels)
    print(f"{name} Clustering")
    print(f"Silhouette Score: {silhouette_avg}")
    print(f"Davies-Bouldin Index: {davies_bouldin_avg}")
    print()

# Đánh giá K-means
evaluate_clustering(rfm_df_scaled, rfm['cluster_km'], "K-means")

# Đánh giá Hierarchical Clustering
evaluate_clustering(rfm_df_scaled, rfm['cluster_hc'], "Hierarchical")
# Out:
# K-means Clustering
# Silhouette Score: 0.44561328115810966
# Davies-Bouldin Index: 0.8181741314129286
#
# Hierarchical Clustering
# Silhouette Score: 0.3521655379848722
# Davies-Bouldin Index: 1.1445262295373801
